# %% [markdown]
# ### Generative AI
# Ask Microsoft Copilot the following question:
# *Create a Python script that uses matplotlib and produces a graph with two curves. The first curve must be a hyperbola with asymptotic lines y = 1 and x = 1, for x between 0 and 1, positive y. The second curve should be the same, with asymptotic lines y = 3 and x = 5, for x between 0 and 3. Legend: "Spreadsheets", "Programming". X-axis title: "Complexity". Tick labels: "Simple", "Medium", "Complex". The y-axis title should be "Time to build".*

# %%
# import complexity_plot

# %%
import codecs

import this
from IPython.display import HTML, display


def fancy_print(text):
    display(
        HTML(f"<pre style='font-size:24px; font-weight:bold;'>{text}</pre>")
    )


# Decode the Zen of Python from ROT13
encoded = this.s
zen = codecs.decode(encoded, "rot_13")

# Display it
fancy_print(zen)

# %%
# Import and execute the plot from complexity_plot.py
# %run complexity_plot.py
