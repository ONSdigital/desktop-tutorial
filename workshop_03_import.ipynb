# %% [markdown]
# # Architecture of Python Projects
# ## What happens when I `import something`?

# %% [markdown]
# ## Motivation
# We want to apply structure to our packages, and to use third-party dependencies
# This means, we often do `import something`.
#
# The goal of this workshop is to understand what exactly happens when we do it,
# what can be imported and from where, and what is the best apporoach

# %%
### Importing Libraries

# %%
import sys

print(sys.version)
print(sys.executable)

# %% [markdown]
# ## What happens when you run
# ```python
# import something # noqa: E402
# ```

# %%
import this

# %% [markdown]
# ### Open questions
# 1. `something` what exactly is it?
# 2. What happens when `something` is found?
# 3. Where does `import` looks for something, and in what order?
# 4. What objects don't need to be imported?
# 5. What objects need to be imported, but don't need to be pip installed.
# 6. I have pip installed something normally (not `-e .`). How does import know where it is?
# 7. I have a script `something.py` in the same directory as `main.py`. Why does it work?
# 8. What if I need to go down?
# 9. what if I need to go up and then down?
# 10. My `import something` worked. How do I know from what absolute path this `something` came from?
# 11. How can I `unimport` something?
# 12. I am running the main script that imports a until. I have changed the util. How do I make sure I import the updated version?
# 13. What is the role of `__init__.py` files?
# 14. What happens when I `pip install -e .`?
# 15. Sometimes, when I run things from different `cwd`, import does not find them. Why?
# 16. **Formulate the best practices**
